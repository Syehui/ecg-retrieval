# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from tqdm.notebook import tqdm

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/prepare-physionet-competition/phycom_data
# /kaggle/input/prepare-physionet-competition/custom.css
# /kaggle/input/prepare-physionet-competition/__notebook__.ipynb
# /kaggle/input/prepare-physionet-competition/label_dict
# /kaggle/input/prepare-physionet-competition/__results__.html
# /kaggle/input/prepare-physionet-competition/__output__.json
# /kaggle/input/prepare-physionet-competition/label_dict_added
# /kaggle/input/prepare-physionet-competition/Dx_map.csv
# /kaggle/input/download-physionet-data/custom.css
# /kaggle/input/download-physionet-data/__notebook__.ipynb
# /kaggle/input/download-physionet-data/phycom_ptbxl_data
# /kaggle/input/download-physionet-data/label_dict
# /kaggle/input/download-physionet-data/__results__.html
# /kaggle/input/download-physionet-data/__output__.json
# /kaggle/input/download-physionet-data/Dx_map.csv
# /kaggle/input/prepare-physionet-competition-expand/phycom_data.gz
# /kaggle/input/prepare-physionet-competition-expand/custom.css
# ...

# %%
#!cp /kaggle/input/prepare-physionet-competition-expand/phycom_data.gz .
# !cp /kaggle/input/prepare-physionet-competition/label_dict .
# !cp /kaggle/input/prepare-physionet-competition/label_dict_added .
# !cp /kaggle/input/prepare-physionet-competition/Dx_map.csv .

from random import shuffle
import gzip
physionet_add = '../input/prepare-physionet-competition-expand/phycom_data.gz'
physionet_f = gzip.open(physionet_add,'rt')
datas = []
for line in physionet_f:
    datas.append(line)

shuffle(datas)

f = gzip.open('phycom_data.gz','wt+')
#f = open('phycom_data','w+')
for line in tqdm(datas):
    f.write(line)
    if line[-1] != '\n':
        f.write('\n')

#sum([1 for line in open('phycom_data')])

# %%
"""num_label = sum([1 for line in open('label_dict_added')])
num_label

import gzip
import base64
f = gzip.open('/kaggle/input/prepare-physionet-competition/phycom_data','rt')
#new_f = gzip.open('phycom_data.gz','wt+')
new_f = open('phycom_data','w+')
shape = []
count = 0
for line in tqdm(f):
    file_name, index_data, index_label, index_feature = line.strip().split('\t')
    index_data = base64.b64decode(index_data)
    index_data = np.frombuffer(index_data, dtype=np.float16).reshape(-1,12)
    
    if(np.isfinite(index_data).all() == False):
        #pass
        continue
    
    index_label = base64.b64decode(index_label)
    index_label = np.frombuffer(index_label, dtype=np.float16)
    label = np.zeros(num_label)
    label[:len(index_label)] = index_label
    
    num_iter = int(index_data.shape[0] / 5000)
    #print(num_iter)
    if(num_iter == 0): print(index_data.shape)
    for k in range(num_iter):
        st = k*5000
        ed = (k+1)*5000
        #print(st,ed)
        data = index_data[st:ed,:]
        if data.shape[0] == 5000:
            output_str = [file_name, base64.b64encode(data.astype(np.float16)).decode("utf-8"), base64.b64encode(label.astype(np.float16)).decode("utf-8"), index_feature]
            new_f.write('\t'.join(output_str) + '\n')
            count += 1
        else:
            print(data.shape)
    if count >= 25000:
        break
new_f.close()

sum([1 for line in open('phycom_data','r')])

#visualization
# -*- coding:utf-8 -*-
#绘制波形图
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["savefig.format"] = 'png'

# Create new figure and two subplots, sharing both axes
def draw_sample(sample, num_point=1000, title=None):
    
    fig,((I,VR,V1,V4),(II,VL,V2,V5),(III,VF,V3,V6)) = plt.subplots(nrows=3, ncols=4, sharey=True, sharex=True, figsize=(30,15), frameon=False)
    #fig.xlim = (0,num_point)
    #fig.ylim = (-300,300)
    
    I_WAVE = sample[0]
    II_WAVE = sample[1]
    III_WAVE = sample[2]

    VR_WAVE = sample[3]
    VL_WAVE = sample[4]
    VF_WAVE = sample[5]

    V1_WAVE = sample[6]
    V2_WAVE = sample[7]
    V3_WAVE = sample[8]
    V4_WAVE = sample[9]
    V5_WAVE = sample[10]
    V6_WAVE = sample[11]

    st = 0
    ed = num_point

    I.plot(I_WAVE[st:ed])
    I.title.set_text('I')
    II.plot(II_WAVE[st:ed])
    II.title.set_text('II')
    III.plot(III_WAVE[st:ed])
    III.title.set_text('III')

    VR.plot(VR_WAVE[st:ed])
    VR.title.set_text('aVR')
    VL.plot(VL_WAVE[st:ed])
    VL.title.set_text('aVL')
    VF.plot(VF_WAVE[st:ed])
    VF.title.set_text('aVF')

    V1.plot(V1_WAVE[st:ed])
    V1.title.set_text('V1')
    V2.plot(V2_WAVE[st:ed])
    V2.title.set_text('V2')
    V3.plot(V3_WAVE[st:ed])
    V3.title.set_text('V3')
    V4.plot(V4_WAVE[st:ed])
    V4.title.set_text('V4')
    V5.plot(V5_WAVE[st:ed])
    V5.title.set_text('V5')
    V6.plot(V6_WAVE[st:ed])
    V6.title.set_text('V6')

    fig.subplots_adjust(wspace=0, hspace=0)
    plt.xlabel('Time:(1/500)s', fontsize=15)
    #plt.ylabel('Amplitude', fontsize=15)
    if title is not None:
        fig.suptitle(title, fontsize=15)
        fig.savefig(title+'.jpg')
    fig.show()
    
#draw_sample(index_data, 10000, u'test')"""
# Out:
# 'num_label = sum([1 for line in open(\'label_dict_added\')])\nnum_label\n\nimport gzip\nimport base64\nf = gzip.open(\'/kaggle/input/prepare-physionet-competition/phycom_data\',\'rt\')\n#new_f = gzip.open(\'phycom_data.gz\',\'wt+\')\nnew_f = open(\'phycom_data\',\'w+\')\nshape = []\ncount = 0\nfor line in tqdm(f):\n    file_name, index_data, index_label, index_feature = line.strip().split(\'\t\')\n    index_data = base64.b64decode(index_data)\n    index_data = np.frombuffer(index_data, dtype=np.float16).reshape(-1,12)\n    \n    if(np.isfinite(index_data).all() == False):\n        #pass\n        continue\n    \n    index_label = base64.b64decode(index_label)\n    index_label = np.frombuffer(index_label, dtype=np.float16)\n    label = np.zeros(num_label)\n    label[:len(index_label)] = index_label\n    \n    num_iter = int(index_data.shape[0] / 5000)\n    #print(num_iter)\n    if(num_iter == 0): print(index_data.shape)\n    for k in range(num_iter):\n        st = k*5000\n        ed = 
# ...
